# %% [markdown]
# # Project Wattpad
#
# ## Getting Wattpad Data
# This Jupyter Notebook file uses the Wattpad API to get data from Wattpad. The main content that we will use for analysis is the Wattpad Stories. The stories have categories and languages associated with them. The category and language data is also available via the api.
#
# Our main focus here will be to get all the raw data from the api, do the data cleanup and save it into csv files that we will use for analysis later.

# %%
# Import Dependencies
import requests
import json
import numpy as np
import pandas as pd
import csv
import yaml
import os
from pandas.io.json import json_normalize

# %% [markdown]
# Set up for API calls
# We need to first set up the details to be able to make the api calls and define the placeholders for our data files and other variables.

# %%
# Load the config.yaml file to get the api keys and other parameters
with open("./config.yaml") as y:
    cfg = yaml.load(y)

header = {
    "Authorization": "Basic {}".format(cfg["keys"]["API_KEY"]),
    "Content-Type": "application/json",
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.186 Safari/537.36",

    }

# Files to save our data
categories_file_name = "data/categories.csv"
languages_file_name = "data/languages.csv"

# %% [markdown]
# ### Getting the Categories from the Wattpad api
# The Wattpad api provides a call to get a list of categories used to categorize all the stories.
# We will get this list and store it as a csv file fo use later

# %%
################################################################################
# This function makes a Wattpad api call to get a list of all the categories
# It writes all the categories data into a csv file to be used later
################################################################################
def get_categories():
    category_url = "https://www.wattpad.com/v4/categories"
    
    # Make the api call
    req = requests.get(category_url, headers=header)
    category_response = req.json()
    
    # Write to the csv file
    with open(categories_file_name,'w') as csvfile:
        write=csv.writer(csvfile, delimiter=',')
        
        # Write the header row
        write.writerow(["ID","NAME"])
        
        # Loop through the data and write
        for category in category_response["categories"]:
            write.writerow([category["id"],category["name"]])

# %%
# Call the function to get all the categories from Whatpad and then view the data 
# from the csv file that is created to make sure we have usable data
get_categories()

# Open the csv file and read its contents to see if we got all the data right
with open(categories_file_name) as csvfile:
    reader = csv.reader(csvfile, delimiter=",")
    for row in reader:
        print(row)
# Out:
# ['ID', 'NAME']
# ['4', 'Romance']
# ['5', 'Science Fiction']
# ['3', 'Fantasy']
# ['7', 'Humor']
# ['12', 'Paranormal']
# ['8', 'Mystery / Thriller']
# ['9', 'Horror']
# ['11', 'Adventure']
# ['23', 'Historical Fiction']
# ['1', 'Teen Fiction']
# ['6', 'Fanfiction']
# ['2', 'Poetry']
# ['17', 'Short Story']
# ['21', 'General Fiction']
# ['24', 'ChickLit']
# ['14', 'Action']
# ['18', 'Vampire']
# ['22', 'Werewolf']
# ['13', 'Spiritual']
# ['16', 'Non-Fiction']
# ['10', 'Classics']
# ['19', 'Random']

# %% [markdown]
# Getting Languages from Wattpad
# The Wattpad api provides a call to get a list of languages used for all the stories. We will get this list and store it as a csv file fo use later

# %%
################################################################################
# This function makes a Wattpad api call to get a list of all the languages
# It writes all the language code data into a csv file to be used later
################################################################################
def get_languages():
    language_url = "https://www.wattpad.com/v4/languages"
    
    # Make the api call
    req = requests.get(language_url, headers=header)
    category_response = req.json()
    
    # Write to the csv file
    with open(languages_file_name,'w') as csvfile:
        write=csv.writer(csvfile, delimiter=',')
        
        # Write the header row
        write.writerow(["LANGUAGE_CODE"])
        
        # Loop through the data and write 
        for category in category_response["languages"]:
            write.writerow([category["code"]])

# %%
# Make the call to get the languages and then view the data from the csv file that
# is created to make sure we have usable data
get_languages()

# Open the csv file and read its contents to see if we got all the data right
with open(languages_file_name) as csvfile:
    reader = csv.reader(csvfile, delimiter=",")
    for row in reader:
        print(row)
# Out:
# ['LANGUAGE_CODE']
# ['en']
# ['fr']
# ['it']
# ['de']
# ['es']
# ['pt-PT']
# ['pt-BR']
# ['ru']
# ['zh-TW']
# ['ja']
# ['ko']
# ['zh-CN']
# ['nl']
# ['pl']
# ['ro']
# ['ar']
# ['he']
# ['tl']
# ['vi']
# ['id']
# ['hi']
# ['ms']
# ['tr']
# ['cs']
# ['ml']
# ['sv']
# ['nn']
# ['hu']
# ['da']
# ['el']
# ['fa']
# ['th']
# ['is']
# ['fi']
# ['et']
# ['lv']
# ['lt']
# ['ca']
# ['bs']
# ['sr']
# ['hr']
# ['sl']
# ['bg']
# ['sk']
# ['be']
# ['uk']
# ['bn']
# ['ur']
# ['ta']
# ['sw']
# ['af']
# ['gu']
# ['or']
# ['pa']
# ['as']
# ['mr']

# %% [markdown]
# ### Getting Stories from Wattpad
# The main content we will be working with is Wattpad stories. The api gives us a list of stories written by users that are read by all the users. We will use this content for our analysis.

# %%
def get_stories(x):
    BASE_URL = "https://www.wattpad.com/v4/stories?limit=100offset%3D0&offset=" + str(x) + "&filter=new"

    req = requests.get(BASE_URL.format("stories"), headers=header)
    json_response = req.json()
    return(json_response)

# %%
#number of stories
N = 10000
json_list = []
for x in np.arange(0, N, 100):
    json_list.append(get_stories(x))

# %%
pages_of_stories = [x['stories'] for x in json_list]

# %%
################################################################################
# Creates a single array of all stories downloaded, parses each json element
# into its own column, then changes the values of the categories column to be
# a single integer instead of an array.
################################################################################

flat_list=[x for y in pages_of_stories for x in y]

stories_df = json_normalize(flat_list)

for i in range(len(stories_df['categories'])):
    stories_df.loc[i, 'categories'] = stories_df['categories'][i][0]
    
stories_df.to_csv(os.path.join('Data', 'stories_3_13_2018_new.csv'))

# %%
stories_df.categories.unique()
# Out:
# array([ 6, 17,  7, 19,  8,  2, 23, 11,  4, 14,  1, 16, 12,  3,  5, 21, 18,
#        13, 22,  9, 24])

# %%
thr_df = pd.read_csv(os.path.join('Data', 'stories_3_09_2018.csv'))
fri_df = pd.read_csv(os.path.join('Data', 'stories_3_10_2018.csv'))
sat_df = pd.read_csv(os.path.join('Data', 'stories.csv'))
mon_new_df = pd.read_csv(os.path.join('Data', 'stories_3_12_2018_new.csv'))
mon_df = pd.read_csv(os.path.join('Data', 'stories_3_12_2018.csv'))

# %%
frames = [thr_df, fri_df, sat_df, mon_df, mon_new_df]
stories_concat = pd.concat(frames)
stories_df = stories_concat.drop_duplicates(subset='id')

# %%
stories_df
# Out:
#       Unnamed: 0 categories  commentCount  completed  copyright  \
# 0              0    [19, 0]          5184       True          1
# 1              1    [19, 0]           132      False          1
# 2              2    [19, 0]          9695       True          0
# 1472  2018-02-24T15:37:12Z    False
# 1473  2018-02-12T12:21:30Z    False
# 1474  2018-03-13T23:11:24Z    False
# 1475  2018-01-10T09:57:20Z    False
# 1476  2018-02-25T03:34:25Z    False
# 1477  2018-03-03T15:49:07Z    False
# 1478  2017-10-05T21:49:55Z    False
# 1479  2018-02-24T04:00:03Z    False
# 1480  2018-02-24T20:49:14Z    False
# 1481  2018-02-13T02:04:18Z    False
# 1482  2017-12-26T17:07:10Z    False
# 1483  2018-02-12T01:30:49Z    False
# 1484  2018-03-13T22:28:09Z    False
# 1485  2018-03-13T22:51:56Z    False
# 1486  2018-02-22T20:46:32Z    False
# 1487  2018-03-13T04:07:31Z    False
# 1488  2018-03-13T20:21:45Z    False
# 1489  2017-08-14T01:48:26Z    False
# 1490  2017-12-22T00:14:28Z    False
# 1491  2017-02-01T20:22:24Z    False
# 1492  2018-03-06T18:57:43Z    False
# 1493  2017-08-26T08:57:22Z    False
#
#                                             description    ...      \
# 0     Fina is a Enforcers Daughter, she's been harsh...    ...
# 1                       ⓠⓤⓞⓣⓔⓢ ⓣⓗⓐⓣ ⓦⓘⓛⓛ ⓜⓐⓚⓔ ⓨⓞⓤ ⓛⓐⓤⓖⓗ    ...
# 2                                            yessss!!!!    ...
# 3                                                   NaN    ...
# 4     Toni  Randall is the daughter Full Moon packs ...    ...
# 5     Alexzandria (Alex) Parker had a difficult fami...    ...
# 6     Hopefully this book makes your life a little e...    ...
# 7     Meet Kyleigh Hawthorne. She's The New Girl At ...    ...
# 8     This is a compilation of my favourite books on...    ...
# 9                                                   NaN    ...
# 10    Warning boyxboy. Jayden Walker is a 17 year ol...    ...
# 11    Hi, my name is Bella, and I'm just the ordinar...    ...
# 12    They say all is fair in love and war.... well ...    ...
# 13                                                  NaN    ...
# 14                                                  NaN    ...
# 15                                                  NaN    ...
# 16                                                  NaN    ...
# 17    Yuki Akuma is the newest student at Ouran Acad...    ...
# 18    This is a series if Sterek smut. As in lemons ...    ...
# 19                                                  NaN    ...
# 20    (Sonamy AU)\n{Under Editing}\n\nMeet Amy Rose,...    ...
# 21                                                  NaN    ...
# 22                                                  NaN    ...
# 23    Yung' feeling na alam ni crush na may crush ka...    ...
# 24                                                  NaN    ...
# 25                                                  NaN    ...
# 26    A girl can only take so much  , that is when y...    ...
# 27    Its a fanfiction about blackpink's jenlisa and...    ...
# 28    Maddie had been going to the same school all h...    ...
# 29    The five heroes. They all have their story end...    ...
# ...                                                 ...    ...
# 1464  She grew up on a lowly island with only her vi...    ...
# 1465                                                NaN    ...
# 1466  "Hey. I'm Athena Lock, The Everything."\n\n"Hi...    ...
# 1467  Crash landing on a hard marble floor wasn't ex...    ...
# 1468  ❝  A veces deseaba no haber encontrado a su al...    ...
# 1469  "you're as sweet as a peach!"\n\n\n\n\n\n\n\n\...    ...
# 1470  And,they meet again,soon.\n\n(Sequel to 'Mutua...    ...
# 1471  part 2 of diary and random crap\nNo need to re...    ...
# 1472  This is a book of all of my fantasy OCs! Some ...    ...
# 1473  This story is about a 17 year old girl who is ...    ...
# 1474  TAKE A PICTURE WHILE IT LASTS -JUNGKOOK\n- - -...    ...
# 1475  Now that Emily Maxwell has gotten her deliciou...    ...
# 1476                                         Spam book.    ...
# 1477  No one was supposed to find out, no one.\n\nNo...    ...
# 1478  Adrien is finally getting to go to a public sc...    ...
# 1479  Eliza, in urgent need of a husband, has found ...    ...
# 1480  What if Leo never found Calypso? What if a new...    ...
# 1481  I just want to be heard. Read and spread the w...    ...
# 1482  This is where I will make forms/outfits/ect fo...    ...
# 1483  sorry if I spell his name wrong I haven't use ...    ...
# 1484         The thing we always needed, but never made    ...
# 1485   ~Vkook~\n~sorry if you no likey~\n~might delete~    ...
# 1486  I was making this for a friend but not anymore...    ...
# 1487  It is around this time that Steampunk's and ot...    ...
# 1488  Newt has had many detective partners over the ...    ...
# 1489  •🍃We're not just greasers🍃•||\n\nYes another  ...    ...
# 1490  Just somewhere to talk and stuff about me I gu...    ...
# 1491                    I'm bored, what else can I say?    ...
# 1492                          You're Mine and Only Mine    ...
# 1493  Thoughts, poems, journal entries.\n\nPossible ...    ...
#
#                                                   parts rating  readCount  \
# 0     [{'id': 36978107, 'title': 'Prologue', 'url': ...      3    2682656
# 1     [{'id': 264398992, 'title': '①. ', 'url': 'htt...      0      76278
# 2     [{'id': 141082265, 'title': 'lol!', 'url': 'ht...      0    1335249
# 3     [{'id': 50914516, 'title': 'Escorting the Brut...      3    8548656
# 4     [{'id': 10656623, 'title': 'My Alpha JERK!', '...      3     733955
# 5     [{'id': 22313394, 'title': 'Behind closed door...      3     735214
# 6     [{'id': 77721987, 'title': 'HIII', 'url': 'htt...      1     900546
# 7     [{'id': 27208138, 'title': 'Changed', 'url': '...      3     661239
# 8     [{'id': 98345726, 'title': '3 Stepbrothers', '...      0     483788
# 9     [{'id': 2583492, 'title': 'Prologue - Edited',...      1    9520817
# 10    [{'id': 26555220, 'title': 'Love Mates (boyxbo...      3     157559
# 11    [{'id': 60689477, 'title': 'Chapter One', 'url...      1     241280
# 12    [{'id': 26922409, 'title': 'Rejection is not a...      3     481006
# 13    [{'id': 5411100, 'title': 'Chapter 1: The new ...      1     489271
# 14    [{'id': 98435470, 'title': 'Aaliyah Mendes', '...      0     393509
# 15    [{'id': 25437254, 'title': 'Kiss me (girlxgirl...      3     598417
# 16    [{'id': 136142573, 'title': 'Chapter 1', 'url'...      1     290924
# 17    [{'id': 71386837, 'title': 'Arrival of The New...      1      58942
# 18    [{'id': 293905716, 'title': 'I know what you a...      1      16396
# 19    [{'id': 109556655, 'title': '1- Your Origin', ...      0      66424
# 20    [{'id': 257839908, 'title': 'Trailer', 'url': ...      1      60247
# 21    [{'id': 197085367, 'title': 'Morning time', 'u...      0     233377
# 22    [{'id': 20087557, 'title': 'Black Heart[gxg]',...      1    1584951
# 23    [{'id': 189918000, 'title': 'Crush Problems 1'...      0     253654
# 24    [{'id': 158842666, 'title': 'Chapter 1', 'url'...      1     170395
# 25    [{'id': 20899589, 'title': 'P. 1', 'url': 'htt...      1     219176
# 26    [{'id': 411031478, 'title': 'CHAPTER 1', 'url'...      1      82105
# 27    [{'id': 530946005, 'title': 'STARE💖 watch the ...      0       1844
# 28    [{'id': 15742021, 'title': 'Chapter three', 'u...      3      57614
# 29    [{'id': 44126008, 'title': 'Merged Worlds', 'u...      0     249546
# ...                                                 ...    ...        ...
# 1464  [{'id': 473153710, 'title': 'Intro     (pictur...      1         63
# 1465  [{'id': 527777809, 'title': '"I actually defin...      0         19
# 1466  [{'id': 523855584, 'title': 'Athena Grace Lock...      0          9
# 1467  [{'id': 419596829, 'title': 'Hello!!!', 'url':...      1        449
# 1468  [{'id': 547232093, 'title': '♡; information', ...      1          2
# 1469  [{'id': 515496577, 'title': '                 ...      0        248
# 1470  [{'id': 545518957, 'title': 'Intro ', 'url': '...      0         56
# 1471  [{'id': 531542776, 'title': 'hi', 'url': 'http...      0        180
# 1472  [{'id': 543841421, 'title': 'Vladimir', 'url':...      0         76
# 1473  [{'id': 534441661, 'title': 'First Day', 'url'...      0         58
# 1474  [{'id': 547255572, 'title': 'CHAPTER 1', 'url'...      0          0
# 1475  [{'id': 520096510, 'title': 'Cast and Introduc...      1     155040
# 1476  [{'id': 539901469, 'title': 'Well..', 'url': '...      0       1141
# 1477  [{'id': 542875996, 'title': 'Characters.', 'ur...      0          4
# 1478  [{'id': 478325307, 'title': 'Description ', 'u...      0        927
# 1479  [{'id': 539423399, 'title': 'A Real Man', 'url...      0          1
# 1480  [{'id': 539755724, 'title': 'Chapter 1', 'url'...      1          5
# 1481  [{'id': 534710743, 'title': 'My Personal Defin...      0         17
# 1482  [{'id': 512874381, 'title': 'Sapphire Maye - A...      0        211
# 1483  [{'id': 534275122, 'title': ' announcement', '...      1         57
# 1484  [{'id': 547242293, 'title': 'Andrew Garfield',...      1          0
# 1485  [{'id': 547249701, 'title': 'Intro ', 'url': '...      0          0
# 1486  [{'id': 538872441, 'title': 'A/N', 'url': 'htt...      0          0
# 1487  [{'id': 546953235, 'title': 'In the begining',...      0          6
# 1488  [{'id': 547200768, 'title': 'One', 'url': 'htt...      1          0
# 1489  [{'id': 455610413, 'title': '💜 Yes another one...      0       1877
# 1490  [{'id': 511225105, 'title': 'Just a thought', ...      0       1752
# 1491  [{'id': 367072413, 'title': 'So...', 'url': 'h...      1       1081
# 1492  [{'id': 544266874, 'title': 'One', 'url': 'htt...      1         41
# 1493  [{'id': 461260358, 'title': 'Endings', 'url': ...      3         76
#
#                                                    tags  \
# 0     ['alpha', 'curse', 'luna', 'magic', 'power', '...
# 1                                                    []
# 2        ['dumb', 'funny', 'listen', 'nothing', 'okay']
# 3                                                    []
# 4                                                    []
# 5                                ['student', 'teacher']
# 6             ['easy', 'hacks', 'life', 'lige', 'like']
# 7     ['brothers', 'drama', 'girl', 'high', 'near-de...
# 8                           ['best', 'book', 'wattpad']
# 9                                                    []
# 10      ['boyxboy', 'cute', 'romance', 'slave', 'yaoi']
# 11     ['boy', 'hawaii', 'mermaid', 'ocean', 'rescued']
# 12    ['drama', 'fiction', 'mate', 'rejection', 'teen']
# 13                                                   []
# 14                                                   []
# 15                                                   []
# 16                                                   []
# 17    ['club', 'high', 'host', 'morixoc', 'ouran', '...
# 18    ['derek', 'fanfic', 'gay', 'sterek', 'stiles',...
# 19                                                   []
# 20    ['bully', 'college', 'comedy', 'drama', 'roman...
# 21                                                   []
# 22                                                   []
# 23    ['crush', 'crushproblems', 'love', 'problems',...
# 24                                                   []
# 25                                                   []
# 26    ['arrogant', 'billionaire', 'cheating', 'ex-wi...
# 27    ['blackpink', 'bts', 'chaesoo', 'forever', 'je...
# 28                                                   []
# 29    ['brave', 'elsa', 'eugunzel', 'frozen', 'hiccu...
# ...                                                 ...
# 1464                     ['fictional', 'notalovestory']
# 1465                                            ['ocs']
# 1466  ['athenagracelock', 'barryallen', 'friendzone'...
# 1467  ['avengers', 'avengersassemble', 'different', ...
# 1468  ['ahgase', 'angst', 'boyxboy', 'gay', 'got7', ...
# 1469  ['ginnyweasley', 'girlxgirl', 'gxg', 'harrypot...
# 1470                                 ['gatenmatarazzo']
# 1471  ['mygayshit', 'mylife', 'mylifeinanutshell', '...
# 1472  ['dracula', 'hybrids', 'mermaids', 'vampireque...
# 1473        ['fanfic', 'highschool', 'love', 'romance']
# 1474                                       ['jungkook']
# 1475  ['badboy', 'crazy', 'doctor', 'erotica', 'gyne...
# 1476  ['bullied', 'hated', 'notcompleted', 'triggered']
# 1477  ['alternateuniverse', 'bangtan', 'blockb', 'bt...
# 1478          ['emo', 'miraculous', 'suicidalthoughts']
# 1479  ['alexander', 'eliza', 'george', 'hamilton', '...
# 1480  ['camphalfblood', 'daughterofposeidon', 'fraze...
# 1481                                        ['ageplay']
# 1482      ['forms', 'fun', 'ocs', 'random', 'roleplay']
# 1483  ['age18', 'book2018', 'brandonrowland', 'chang...
# 1484  ['andrewgarfield', 'angelenajolie', 'caradelev...
# 1485  ['btsfanfic', 'bxb', 'hoseok', 'jimin', 'jungk...
# 1486          ['alena', 'love', 'lovestory', 'lurance']
# 1487                   ['death', 'fantasy', 'violence']
# 1488  ['alby', 'aris', 'brenda', 'chuck', 'detective...
# 1489  ['60s', 'book', 'fanfiction', 'greaser', 'john...
# 1490                   ['character', 'mbs', 'roleplay']
# 1491                                     ['randomness']
# 1492  ['alpha', 'angst', 'bangtan', 'bts', 'floof', ...
# 1493  ['afraidtofall', 'asexual', 'ftm', 'greyace', ...
#
#                                                   title  \
# 0                                      Hadar #Watty2014
# 1                                  Funny quotes  part 1
# 2                                    ❇awsome comebacks❇
# 3                                   Escorting the Brute
# 4                              My Alpha JERK! (On Hold)
# 5         Behind closed doors (teacher/student romance)
# 6                                          Life Hacks!!
# 7                                               Changed
# 8                                  Best Wattpad Stories
# 9                     Hush, Howl (Complete and Editing)
# 10                                 Love Mates (boyxboy)
# 11                                      I Sea a Mermaid
# 4                                         NaN               nesha23      14432
# 5                                         NaN   PissedImNotAMermaid      13625
# 6                                         NaN            UglyNugget      20952
# 7                                         NaN          Sugar-Quills      13523
# 8                                         gel       flawlesslikegel       3088
# 9                                      Lovely        MyLovelyWriter     121956
# 10                                        NaN             Alicat589       3321
# 11                            XxCloverheartxX          WattyMelon10       7602
# 12                                   Hey, fam              1Chelsea      15309
# 13                                        NaN          TeamTwilight      11625
# 14                               Taylor Flood      younowbabes4life       1431
# 15                                        NaN          love_shannon      13013
# 16                                        NaN           amberwolf89      10883
# 17                                        NaN         Demon_D_Raika       2460
# 18                              Freja Sentaro          grayismylife        186
# 19                          Little Miss Lezza               lilezza       2105
# 20                            ąŋɖ קɛɠɠყ (´∀`)     XxSA_ChillidogsxX       2343
# 21                                        NaN            maddyturnt       2747
# 22                                  Thea Mary        SanEmLexRiss14      34782
# 23                              FVÇK Ü HÅT3RZ   Ihateannoyingpeople       7320
# 24                                        NaN           amberwolf89       8019
# 25                                        ^-^             CupHugger       6092
# 26                                        NaN           Harmonica36       3037
# 27                                        NaN           arcymeneses         18
# 28                               Jem Pearsall           JemPearsall        573
# 29                                       Luna      Flaming-Darkness      10504
# ...                                       ...                   ...        ...
# 1464                             Caitlin Byrd          super_river7          0
# 1465                              ✨Smol Baby✨           lil-mochiii          7
# 1466                                      NaN               Srh3307          0
# 1467                                      lia               xbexxed         14
# 1468                     ¡ c l (oser) a r y !              H0NEYEOM          3
# 1469                                     aly!           wonderfuls-         40
# 1470                                       ❤️  Whydontwelove1111111          9
# 1471  Piløts! falling at the chemical (Tay*W)                OofEll         86
# 1472                         Sergeant Courage   ARC_Trooper_Courage         14
# 1473                           dannyover_load        dannyover_load         15
# 1474                                 xxtiffxx             ilovetiff          0
# 1475                             Divine Grace              dgkitten       4985
# 1476                                    Deuce          lone_greaser        286
# 1477                           Kiana Nichelle        brownsugazucar          0
# 1478                                      NaN           blackcat212         66
# 1479                          Mr.Judgemental.               p_len03          0
# 1480                     Daughter Of Poseidon             sarahsazz          2
# 1481                            Sarah Fandoms            TheRealSRF          0
# 1482                                     Birb               Bi_Birb          4
# 1483                            Paola Delgado         pandasinger12          7
# 1484                                 MAJORTOM              EmmilyGB          0
# 1485                               poTAEtoes3            poTAEtoes3          0
# 1486                        KatieMarie Hansen     KatieMarieHansen7          0
# 1487                                      NaN             Jakester9          0
# 1488                                      NaN       Fairylights4672          0
# 1489                              •✨Delaney✨•           delaney__22        216
# 1490                                      𝙽𝙾𝚆        SoldierOfStars        511
# 1491                             Little Tiger        Gekido_Inferno         89
# 1492                                     Army            episodekat          2
# 1493                                    Jaden             noodlegod         37
#
# [3573 rows x 32 columns]

# %%
stories_merge.to_csv(os.path.join('Data', 'stories_merge.csv'))

# %% [markdown]
# ## Data Munging

# %% [markdown]
# ### Removing unwanted rows

# %%
# read in data
df = pd.read_csv(os.path.join('Data', 'stories_3_12_2018_new.csv'))

# %%
# remove rows without tags
df = df.loc[df['tags'] != '[]']

# %%
# remove NaN descriptions
df=df.loc[[len(str(x)) > 4 for x in df['description']]]

# %%
df.head()
# Out:
#    Unnamed: 0  categories  commentCount  completed  copyright  \
# 0           0           6            12      False          1
# 1           1          17             0      False          1
# 2           2          17             0      False          1
# 3           3           7             0      False          1
# 4           4          19           200      False          1
#
#                                                cover       cover_timestamp  \
# 0  https://a.wattpad.com/cover/129173744-256-k151...  2017-12-02T02:06:21Z
# 1  https://a.wattpad.com/cover/141691720-256-k874...  2018-03-13T00:15:43Z
# 2  https://a.wattpad.com/cover/141267339-256-k611...  2018-03-10T00:08:20Z
# 3  https://a.wattpad.com/cover/141129404-256-k400...  2018-03-07T13:31:33Z
# 4  https://a.wattpad.com/cover/136339277-256-k619...  2018-03-10T02:23:45Z
#
#              createDate  deleted  \
# 0  2017-11-18T19:52:12Z    False
# 1  2018-03-13T00:15:42Z    False
# 2  2018-03-09T00:26:38Z    False
# 3  2018-03-07T13:31:32Z    False
# 4  2018-01-24T06:04:34Z    False
#
#                                          description    ...      \
# 0  [ coming soon ]\n\nIn which a regular 19 year ...    ...
# 1                                           swallow!    ...
# 2  I don't see many of these and I'm not sure if ...    ...
# 3  Read some of these funny memes! * I did not ma...    ...
# 4  unpopular opinions.\n\n❝ you have married an i...    ...
#
#                                                parts rating  readCount  \
# 0  [{'id': 496588471, 'title': 'Mr Country Club |...      0         63
# 1  [{'id': 546886656, 'title': 'impudence!', 'url...      0          0
# 2  [{'id': 545128060, 'title': 'Oneshot 1: Rulers...      1         32
# 3  [{'id': 544550562, 'title': 'Part 1', 'url': '...      0          8
# 4  [{'id': 526165586, 'title': 'burn.', 'url': 'h...      1        629
#
#                                                 tags  \
# 0  ['collinskey', 'devankey', 'keybros', 'keypers...
# 1  ['aesthetic', 'blood', 'death', 'detective', '...
# 2             ['lesbian', 'oneshot', 'readerxcrush']
# 3                 ['fun', 'funny', 'humor', 'memes']
# 4  ['gender', 'movies', 'opinions', 'pennywise', ...
#
#                                           title  \
# 0  Mr Country Club | devan key [ coming soon ]
# 1                                    the offing
# 2                  Female Crush X Female Reader
# 3               F̺͆u̺͆n̺͆n̺͆y̺͆ M̺͆e̺͆m̺͆e̺͆s̺͆
# 4                     BURN | unpopular opinions
#
#                                                  url  \
# 0  https://www.wattpad.com/story/129173744-mr-cou...
# 1  https://www.wattpad.com/story/141691720-the-of...
# 2  https://www.wattpad.com/story/141267339-female...
# 3  https://www.wattpad.com/story/141129404-f%CD%8...
# 4  https://www.wattpad.com/story/136339277-burn-u...
#
#                                          user.avatar  user.fullname  \
# 0  https://a.wattpad.com/useravatar/voidtube.128....        chelsea
# 1  https://a.wattpad.com/useravatar/sunfully.128....              ♡
# 2  https://a.wattpad.com/useravatar/Dem0g0rgon.12...            NaN
# 3  https://a.wattpad.com/useravatar/_Daily_News_....            NaN
# 4  https://a.wattpad.com/useravatar/dacrethotgome...          benny
#
#          user.name  voteCount
# 0         voidtube          5
# 1         sunfully          0
# 2       Dem0g0rgon          4
# 3     _Daily_News_          0
# 4  dacrethotgomery         95
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Removing unwanted columns
# We have some unwanted columns in the table so we will remove them and create a stripped down version of the data frame that we will work with for the analysis.
# The following columns are removed:
# * Unnamed: 0
# * copyright
# * cover
# * cover_timestamp
# * firstPartId
# * firstPublishedPart.createDate
# * firstPublishedPart.id
# * lastPublishedPart.createDate
# * lastPublishedPart.id
# * parts

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'categories', 'commentCount', 'completed', 'copyright',
#        'cover', 'cover_timestamp', 'createDate', 'deleted', 'description',
#        'firstPartId', 'firstPublishedPart.createDate', 'firstPublishedPart.id',
#        'id', 'language.id', 'language.name', 'lastPublishedPart.createDate',
#        'lastPublishedPart.id', 'length', 'mature', 'modifyDate', 'numParts',
#        'parts', 'rating', 'readCount', 'tags', 'title', 'url', 'user.avatar',
#        'user.fullname', 'user.name', 'voteCount'],
#       dtype='object')

# %%
# remove the unwanted columns to minimize clutter
stripped_df = df[["categories","commentCount","completed",
                  "createDate","deleted","description","id", 
                  "language.id","language.name","length","mature",
                  "modifyDate","numParts","rating","readCount",
                  "tags","title","url","user.avatar","user.fullname",
                  "user.name","voteCount"]]

# %% [markdown]
# ### Merging with the categories data
# The categories in the stories list is listed as an id so we need to get the corresponding category names into this dataframe. We will also rename and reorder the columns to make more logical sense

# %%
categories_df = pd.read_csv('Data/categories.csv')
categories_df
# Out:
#     ID                NAME
# 0    4             Romance
# 1    5     Science Fiction
# 2    3             Fantasy
# 3    7               Humor
# 4   12          Paranormal
# 5    8  Mystery / Thriller
# 6    9              Horror
# 7   11           Adventure
# 8   23  Historical Fiction
# 9    1        Teen Fiction
# 10   6          Fanfiction
# 11   2              Poetry
# 12  17         Short Story
# 13  21     General Fiction
# 14  24            ChickLit
# 15  14              Action
# 16  18             Vampire
# 17  22            Werewolf
# 18  13           Spiritual
# 19  16         Non-Fiction
# 20  10            Classics
# 21  19              Random

# %%
# Add a new column to put in the corresponding category names
stripped_df["categoryName"] = stripped_df["categories"]
stripped_df["categoryName"].unique()
# Out:
# /Users/acanois/anaconda2/envs/ds3/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# array([ 6, 17,  7, 19,  8,  2, 23,  4, 14,  1, 16, 12,  3,  5, 21, 11, 18,
#        13, 22,  9, 24])

# %%
# Function to get the category name from the categories_df given the category id
def get_category(x):
    name = categories_df.loc[categories_df["ID"]==int(x),"NAME"]
    return name.iloc[0]

# Replace the id with name in the categoryName column
stripped_df["categoryName"] = stripped_df["categoryName"].apply(get_category)
stripped_df["categoryName"].unique()
# Out:
# /Users/acanois/anaconda2/envs/ds3/lib/python3.6/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# array(['Fanfiction', 'Short Story', 'Humor', 'Random',
#        'Mystery / Thriller', 'Poetry', 'Historical Fiction', 'Romance',
#        'Action', 'Teen Fiction', 'Non-Fiction', 'Paranormal', 'Fantasy',
#        'Science Fiction', 'General Fiction', 'Adventure', 'Vampire',
#        'Spiritual', 'Werewolf', 'Horror', 'ChickLit'], dtype=object)

# %%
# rename some columns to keep the column name format consistent
stripped_df = stripped_df.rename(columns={"categories":"categoryId",
                            "language.id": "languageId",
                            "language.name": "languageName",
                            "user.avatar": "userAvatar",
                            "user.fullname":"userFullname",
                            "user.name":"userName"})

# reorder the columns
stripped_df = stripped_df[["id","title","description","url","createDate",
                          "modifyDate","completed","numParts","deleted","length",
                          "categoryId","categoryName","languageId","languageName","mature","rating",
                          "tags","commentCount","readCount","voteCount","userAvatar","userFullname","userName"]]
stripped_df.head()
# Out:
#           id                                         title  \
# 0  129173744  Mr Country Club | devan key [ coming soon ]
# 1  141691720                                    the offing
# 2  141267339                  Female Crush X Female Reader
# 3  141129404               F̺͆u̺͆n̺͆n̺͆y̺͆ M̺͆e̺͆m̺͆e̺͆s̺͆
# 4  136339277                     BURN | unpopular opinions
#
#                                          description  \
# 0  [ coming soon ]\n\nIn which a regular 19 year ...
# 1                                           swallow!
# 2  I don't see many of these and I'm not sure if ...
# 3  Read some of these funny memes! * I did not ma...
# 4  unpopular opinions.\n\n❝ you have married an i...
#
#                                                  url            createDate  \
# 0  https://www.wattpad.com/story/129173744-mr-cou...  2017-11-18T19:52:12Z
# 1  https://www.wattpad.com/story/141691720-the-of...  2018-03-13T00:15:42Z
# 2  https://www.wattpad.com/story/141267339-female...  2018-03-09T00:26:38Z
# 3  https://www.wattpad.com/story/141129404-f%CD%8...  2018-03-07T13:31:32Z
# 4  https://www.wattpad.com/story/136339277-burn-u...  2018-01-24T06:04:34Z
#
#              modifyDate  completed  numParts  deleted  length  \
# 0  2018-03-13T23:54:10Z      False         3    False    7590
# 1  2018-03-13T23:54:11Z      False         3    False    1676
# 2  2018-03-13T23:54:08Z      False         3    False   24132
# 3  2018-03-13T23:54:08Z      False         4    False     203
# 4  2018-03-13T23:54:07Z      False        15    False   17044
#
#         ...         languageName mature  rating  \
# 0       ...              English  False       0
# 1       ...              English  False       0
# 2       ...              English  False       1
# 3       ...              English  False       0
# 4       ...              English  False       1
#
#                                                 tags  commentCount  readCount  \
# 0  ['collinskey', 'devankey', 'keybros', 'keypers...            12         63
# 1  ['aesthetic', 'blood', 'death', 'detective', '...             0          0
# 2             ['lesbian', 'oneshot', 'readerxcrush']             0         32
# 3                 ['fun', 'funny', 'humor', 'memes']             0          8
# 4  ['gender', 'movies', 'opinions', 'pennywise', ...           200        629
#
#   voteCount                                         userAvatar  userFullname  \
# 0         5  https://a.wattpad.com/useravatar/voidtube.128....       chelsea
# 1         0  https://a.wattpad.com/useravatar/sunfully.128....             ♡
# 2         4  https://a.wattpad.com/useravatar/Dem0g0rgon.12...           NaN
# 3         0  https://a.wattpad.com/useravatar/_Daily_News_....           NaN
# 4        95  https://a.wattpad.com/useravatar/dacrethotgome...         benny
#
#           userName
# 0         voidtube
# 1         sunfully
# 2       Dem0g0rgon
# 3     _Daily_News_
# 4  dacrethotgomery
#
# [5 rows x 23 columns]

# %%
# save the data frame to a csv file to be used for vizualizations later
stripped_df.to_csv(os.path.join('Data', 'stories_for_viz.csv'), index=False)

# %%
len(stripped_df)
# Out:
# 1428
